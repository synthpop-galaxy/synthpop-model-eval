# %%
# %load_ext autoreload
# %autoreload 2
from lumfuncs import StanekWindowLF
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import synthpop

# %%
swlf = StanekWindowLF()

# %%
swlf.run_comparison([],[],[],[],1)
